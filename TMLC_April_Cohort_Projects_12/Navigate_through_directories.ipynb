# %%
import os, sys

# %%
cwd = os.getcwd()
cwd
# Out:
# 'C:\\Users\\Kshitij\\Documents\\solns_new\\TMLC_April_Cohort_Projects_12'

# %%
path = "."
dir = os.listdir( path )

for file in dir:
   print(file)
# Out:
# .ipynb_checkpoints
# Navigate_through_directories.ipynb
# Project_10_Plant Seedling Classification(Image_Classification)
# Project_11_Racoon_Detection(Object_Detection)
# Project_12_Water_body_segmentation_in_Satellite_Images(Image_Segmentation)
# Project_1_Road_Traffic_Severity(Classification)
# Project_2_Site_Energy_Intensity_Prediction(Regression)
# Project_3_Wild_Blueberry_Yield_Prediction(Regression)
# Project_4_Patient_Survival_Prediction(Imbalanaced_Classfication)
# Project_5_Higgs_Boson_Event_Detection(Classification)
# Project_6_DMSP_Particle_Precipitate_Flux_Prediction_Mesoscale(Regression)
# Project_7_Cyberbullying_Detection(Text_Classification)
# Project_8_Game_Of_Thrones(Text_Generation)
# Project_9_English_to_Hindi(Text_Translation)

# %%
path = "."

for root, d_names, f_names in os.walk(path):
   print(root, d_names, f_names)
   print("\n\n")
# Out:
# . ['.ipynb_checkpoints', 'Project_10_Plant Seedling Classification(Image_Classification)', 'Project_11_Racoon_Detection(Object_Detection)', 'Project_12_Water_body_segmentation_in_Satellite_Images(Image_Segmentation)', 'Project_1_Road_Traffic_Severity(Classification)', 'Project_2_Site_Energy_Intensity_Prediction(Regression)', 'Project_3_Wild_Blueberry_Yield_Prediction(Regression)', 'Project_4_Patient_Survival_Prediction(Imbalanaced_Classfication)', 'Project_5_Higgs_Boson_Event_Detection(Classification)', 'Project_6_DMSP_Particle_Precipitate_Flux_Prediction_Mesoscale(Regression)', 'Project_7_Cyberbullying_Detection(Text_Classification)', 'Project_8_Game_Of_Thrones(Text_Generation)', 'Project_9_English_to_Hindi(Text_Translation)'] ['Navigate_through_directories.ipynb']
#
#
#
# .\.ipynb_checkpoints [] ['Navigate_through_directories-checkpoint.ipynb']
#
#
#
# .\Project_10_Plant Seedling Classification(Image_Classification) ['Dataset', 'Desc_and_PS', 'Extra_Resources', 'My_Solution', 'TMLC_Solution'] []
#
#
#
# .\Project_10_Plant Seedling Classification(Image_Classification)\Dataset [] ['NonsegmentedV2.zip', 'Source_of_data.txt']
#
#
#
# .\Project_10_Plant Seedling Classification(Image_Classification)\Desc_and_PS [] ['Description.txt', 'Problem_Statement.txt']
#
#
#
# .\Project_10_Plant Seedling Classification(Image_Classification)\Extra_Resources [] ['CNN for Image Classification.pdf', 'links.txt']
#
#
#
# .\Project_10_Plant Seedling Classification(Image_Classification)\My_Solution [] []
#
#
#
# .\Project_10_Plant Seedling Classification(Image_Classification)\TMLC_Solution [] ['Plant_Seedling_Classification.ipynb']
#
#
#
# .\Project_11_Racoon_Detection(Object_Detection) ['Dataset', 'Desc_and_PS', 'My_Solution', 'TMLC_Solution'] []
#
#
#
# .\Project_11_Racoon_Detection(Object_Detection)\Dataset [] ['Racoon Detection.zip', 'Source_of_data.txt']
#
#
#
# .\Project_11_Racoon_Detection(Object_Detection)\Desc_and_PS [] ['Description.txt', 'Problem_Statement.txt']
#
#
#
# .\Project_11_Racoon_Detection(Object_Detection)\My_Solution [] []
#
#
#
# .\Project_11_Racoon_Detection(Object_Detection)\TMLC_Solution [] ['racoon_detection.ipynb']
#
#
#
# .\Project_12_Water_body_segmentation_in_Satellite_Images(Image_Segmentation) ['Dataset', 'Desc_and_PS', 'Extra_Resources', 'My_Solution', 'TMLC_Solution'] []
#
#
#
# .\Project_12_Water_body_segmentation_in_Satellite_Images(Image_Segmentation)\Dataset [] ['Segmentation Dataset.zip', 'Source_of_data.txt']
#
#
#
# .\Project_12_Water_body_segmentation_in_Satellite_Images(Image_Segmentation)\Desc_and_PS [] ['Description.txt', 'Problem_Statement.txt']
#
#
#
# .\Project_12_Water_body_segmentation_in_Satellite_Images(Image_Segmentation)\Extra_Resources [] ['links.txt']
#
#
#
# .\Project_12_Water_body_segmentation_in_Satellite_Images(Image_Segmentation)\My_Solution ['.ipynb_checkpoints'] ['Water_Body_Segmentation.ipynb']
#
#
#
# .\Project_12_Water_body_segmentation_in_Satellite_Images(Image_Segmentation)\My_Solution\.ipynb_checkpoints [] ['Water_Body_Segmentation-checkpoint.ipynb']
#
#
#
# .\Project_12_Water_body_segmentation_in_Satellite_Images(Image_Segmentation)\TMLC_Solution [] ['Image_Segmentation_with_U_Net_Like_Architecture.ipynb', 'Segmentation_and_Object_Detection.ipynb', 'water-bodies-segmentation-with-unet-and-tensorflow.ipynb']
#
#
#
# .\Project_1_Road_Traffic_Severity(Classification) ['Dataset', 'Desc_and_PS', 'Extra_Resources', 'My_Solution', 'TMLC_Solution'] []
#
#
#
# .\Project_1_Road_Traffic_Severity(Classification)\Dataset [] ['RTA_Dataset.csv', 'Source_of_data.txt']
#
#
#
# .\Project_1_Road_Traffic_Severity(Classification)\Desc_and_PS [] ['Description.txt', 'Problem_Statement.txt']
#
#
#
# .\Project_1_Road_Traffic_Severity(Classification)\Extra_Resources [] ['DIY_RTA_SHAP.ipynb', 'links.docx', 'MGP_Beginners.ipynb', 'Procedure.docx']
#
#
#
# .\Project_1_Road_Traffic_Severity(Classification)\My_Solution ['.ipynb_checkpoints'] ['Accident_Prediction.ipynb']
#
#
#
# .\Project_1_Road_Traffic_Severity(Classification)\My_Solution\.ipynb_checkpoints [] ['Accident_Prediction-checkpoint.ipynb']
#
#
#
# .\Project_1_Road_Traffic_Severity(Classification)\TMLC_Solution [] ['ML Template For Beginners.ipynb', '[New]Guided_SampleNotebook_RTADataset.ipynb']
#
#
#
# .\Project_2_Site_Energy_Intensity_Prediction(Regression) ['Dataset', 'Desc_and_PS', 'My_Solution', 'TMLC_Solution'] []
#
#
#
# .\Project_2_Site_Energy_Intensity_Prediction(Regression)\Dataset [] ['Source_of_data.txt', 'train_dataset.csv', 'x_test.csv', 'y_test.csv']
#
#
#
# .\Project_2_Site_Energy_Intensity_Prediction(Regression)\Desc_and_PS [] ['Description.txt', 'Problem_Statement.txt']
#
#
#
# .\Project_2_Site_Energy_Intensity_Prediction(Regression)\My_Solution [] []
#
#
#
# .\Project_2_Site_Energy_Intensity_Prediction(Regression)\TMLC_Solution [] ['[New]Guided_SampleNotebook_SiteEUIPrediction_WiDS22.ipynb']
#
#
#
# .\Project_3_Wild_Blueberry_Yield_Prediction(Regression) ['Dataset', 'Desc_and_PS', 'My_Solution', 'TMLC_Solution'] []
#
#
#
# .\Project_3_Wild_Blueberry_Yield_Prediction(Regression)\Dataset [] ['Data_in_brief_WildBlueberryPollinationSimulation.docx', 'Source_of_data.txt', 'WildBlueberryPollinationSimulationData.csv', 'Wild_blueberry_yield_prediction_using_a_combination_of_computer_simulation.pdf']
#
#
#
# .\Project_3_Wild_Blueberry_Yield_Prediction(Regression)\Desc_and_PS [] ['Description.txt', 'Problem_Statement.txt']
#
#
#
# .\Project_3_Wild_Blueberry_Yield_Prediction(Regression)\My_Solution [] []
#
#
#
# .\Project_3_Wild_Blueberry_Yield_Prediction(Regression)\TMLC_Solution [] ['[New]Guided_SampleNotebook_WildBberryPollSimPred.ipynb']
#
#
#
# .\Project_4_Patient_Survival_Prediction(Imbalanaced_Classfication) ['Dataset', 'Desc_and_PS', 'Extra_Resources', 'My_Solution', 'TMLC_Solution'] []
#
#
#
# .\Project_4_Patient_Survival_Prediction(Imbalanaced_Classfication)\Dataset [] ['Dataset.csv', 'Data_Dictionary.csv', 'Source_of_data.txt']
#
#
#
# .\Project_4_Patient_Survival_Prediction(Imbalanaced_Classfication)\Desc_and_PS [] ['Description.txt', 'Problem_Statement.txt']
#
#
#
# .\Project_4_Patient_Survival_Prediction(Imbalanaced_Classfication)\Extra_Resources [] ['Deep Learning basic flow.pdf', 'DL1_Patient _Survival_notebook.ipynb', 'Guided_Patient_Survival_Prediction.ipynb', 'links.txt', 'pytorch-nn-baseline-for-beginners.ipynb']
#
#
#
# .\Project_4_Patient_Survival_Prediction(Imbalanaced_Classfication)\My_Solution [] []
#
#
#
# .\Project_4_Patient_Survival_Prediction(Imbalanaced_Classfication)\TMLC_Solution [] ['DL1_Patient _Survival_notebook.ipynb', 'Guided_Patient_Survival_Prediction.ipynb', 'pytorch-nn-baseline-for-beginners.ipynb']
#
#
#
# .\Project_5_Higgs_Boson_Event_Detection(Classification) ['Dataset', 'Desc_and_PS', 'My_Solution', 'TMLC_Solution'] []
#
#
#
# .\Project_5_Higgs_Boson_Event_Detection(Classification)\Dataset [] ['Dataset_Details.docx', 'Dataset_Details.pdf', 'In-depth_details.pdf', 'Searching_for_Higgs_Boson_Decay_Modes_with_Deep_Learning.pdf', 'Source_of_data.txt', 'training.csv']
#
#
#
# .\Project_5_Higgs_Boson_Event_Detection(Classification)\Desc_and_PS [] ['Description.txt', 'Problem_Statement.txt']
#
#
#
# .\Project_5_Higgs_Boson_Event_Detection(Classification)\My_Solution [] []
#
#
#
# .\Project_5_Higgs_Boson_Event_Detection(Classification)\TMLC_Solution [] ['higgsbosoneventdetection.ipynb']
#
#
#
# .\Project_6_DMSP_Particle_Precipitate_Flux_Prediction_Mesoscale(Regression) ['Dataset', 'Desc_and_PS', 'My_Solution', 'TMLC_Solution'] []
#
#
#
# .\Project_6_DMSP_Particle_Precipitate_Flux_Prediction_Mesoscale(Regression)\Dataset [] ['AI_Ready_DMSP_Data.csv', 'Source_of_data.txt']
#
#
#
# .\Project_6_DMSP_Particle_Precipitate_Flux_Prediction_Mesoscale(Regression)\Desc_and_PS [] ['Description.txt', 'Problem_Statement.txt']
#
#
#
# .\Project_6_DMSP_Particle_Precipitate_Flux_Prediction_Mesoscale(Regression)\My_Solution [] []
#
#
#
# .\Project_6_DMSP_Particle_Precipitate_Flux_Prediction_Mesoscale(Regression)\TMLC_Solution [] ['DMSP_Particle_Precipitation.ipynb']
#
#
#
# .\Project_7_Cyberbullying_Detection(Text_Classification) ['Dataset', 'Desc_and_PS', 'Extra_Resources', 'My_Solution', 'TMLC_Solution'] []
#
#
#
# .\Project_7_Cyberbullying_Detection(Text_Classification)\Dataset [] ['Source_of_data.txt', 'twitter_parsed_dataset.csv']
#
#
#
# .\Project_7_Cyberbullying_Detection(Text_Classification)\Desc_and_PS [] ['Description.txt', 'Problem_Statement.txt']
#
#
#
# .\Project_7_Cyberbullying_Detection(Text_Classification)\Extra_Resources [] ['links.docx', 'NLP_Basics.ipynb', 'NLP_Complete.ipynb', 'Text generation using Deep Learning.pdf']
#
#
#
# .\Project_7_Cyberbullying_Detection(Text_Classification)\My_Solution [] []
#
#
#
# .\Project_7_Cyberbullying_Detection(Text_Classification)\TMLC_Solution [] ['Guided_Cyberberbullying_TextClassification_NLP.ipynb']
#
#
#
# .\Project_8_Game_Of_Thrones(Text_Generation) ['Dataset', 'Desc_and_PS', 'My_Solution', 'TMLC_Solution'] []
#
#
#
# .\Project_8_Game_Of_Thrones(Text_Generation)\Dataset [] ['got1.txt', 'Source_of_data.txt']
#
#
#
# .\Project_8_Game_Of_Thrones(Text_Generation)\Desc_and_PS [] ['Description.txt', 'Problem_Statement.txt']
#
#
#
# .\Project_8_Game_Of_Thrones(Text_Generation)\My_Solution [] []
#
#
#
# .\Project_8_Game_Of_Thrones(Text_Generation)\TMLC_Solution [] ['Building_RNN_Text_Generation.ipynb']
#
#
#
# .\Project_9_English_to_Hindi(Text_Translation) ['Dataset', 'Desc_and_PS', 'My_Solution', 'TMLC_Solution'] []
#
#
#
# .\Project_9_English_to_Hindi(Text_Translation)\Dataset [] ['hindi_english_parallel.csv', 'Source_of_data.txt']
#
#
#
# .\Project_9_English_to_Hindi(Text_Translation)\Desc_and_PS [] ['Description.txt', 'Problem_Statement.txt']
#
#
#
# .\Project_9_English_to_Hindi(Text_Translation)\My_Solution [] []
#
#
#
# .\Project_9_English_to_Hindi(Text_Translation)\TMLC_Solution [] ['english-hindi-machine-translation.ipynb']

# %%
path = "./Project_1_Road_Traffic_Severity(Classification)"

fname = []
for root,d_names,f_names in os.walk(path):
   for f in f_names:
      fname.append(os.path.join(root, f))        

print("fname = %s" %fname)
# Out:
# fname = ['./Project_1_Road_Traffic_Severity(Classification)\\Dataset\\RTA_Dataset.csv', './Project_1_Road_Traffic_Severity(Classification)\\Dataset\\Source_of_data.txt', './Project_1_Road_Traffic_Severity(Classification)\\Desc_and_PS\\Description.txt', './Project_1_Road_Traffic_Severity(Classification)\\Desc_and_PS\\Problem_Statement.txt', './Project_1_Road_Traffic_Severity(Classification)\\Extra_Resources\\DIY_RTA_SHAP.ipynb', './Project_1_Road_Traffic_Severity(Classification)\\Extra_Resources\\links.docx', './Project_1_Road_Traffic_Severity(Classification)\\Extra_Resources\\MGP_Beginners.ipynb', './Project_1_Road_Traffic_Severity(Classification)\\Extra_Resources\\Procedure.docx', './Project_1_Road_Traffic_Severity(Classification)\\My_Solution\\Accident_Prediction.ipynb', './Project_1_Road_Traffic_Severity(Classification)\\My_Solution\\.ipynb_checkpoints\\Accident_Prediction-checkpoint.ipynb', './Project_1_Road_Traffic_Severity(Classification)\\TMLC_Solution\\ML Template For Beginners.ipynb', './Project_1_Road_Traffic_Severity(Classification)\\TMLC_Solution\\[New]Guided_SampleNotebook_RTADataset.ipynb']

# %%
for dirpath, dirs, files in os.walk("."):
   print(dirpath) # prints paths of all subdirectories present
# Out:
# .
# .\.ipynb_checkpoints
# .\Project_10_Plant Seedling Classification(Image_Classification)
# .\Project_10_Plant Seedling Classification(Image_Classification)\Dataset
# .\Project_10_Plant Seedling Classification(Image_Classification)\Desc_and_PS
# .\Project_10_Plant Seedling Classification(Image_Classification)\Extra_Resources
# .\Project_10_Plant Seedling Classification(Image_Classification)\My_Solution
# .\Project_10_Plant Seedling Classification(Image_Classification)\TMLC_Solution
# .\Project_11_Racoon_Detection(Object_Detection)
# .\Project_11_Racoon_Detection(Object_Detection)\Dataset
# .\Project_11_Racoon_Detection(Object_Detection)\Desc_and_PS
# .\Project_11_Racoon_Detection(Object_Detection)\My_Solution
# .\Project_11_Racoon_Detection(Object_Detection)\TMLC_Solution
# .\Project_12_Water_body_segmentation_in_Satellite_Images(Image_Segmentation)
# .\Project_12_Water_body_segmentation_in_Satellite_Images(Image_Segmentation)\Dataset
# .\Project_12_Water_body_segmentation_in_Satellite_Images(Image_Segmentation)\Desc_and_PS
# .\Project_12_Water_body_segmentation_in_Satellite_Images(Image_Segmentation)\Extra_Resources
# .\Project_12_Water_body_segmentation_in_Satellite_Images(Image_Segmentation)\My_Solution
# .\Project_12_Water_body_segmentation_in_Satellite_Images(Image_Segmentation)\My_Solution\.ipynb_checkpoints
# .\Project_12_Water_body_segmentation_in_Satellite_Images(Image_Segmentation)\TMLC_Solution
# .\Project_1_Road_Traffic_Severity(Classification)
# .\Project_1_Road_Traffic_Severity(Classification)\Dataset
# .\Project_1_Road_Traffic_Severity(Classification)\Desc_and_PS
# .\Project_1_Road_Traffic_Severity(Classification)\Extra_Resources
# .\Project_1_Road_Traffic_Severity(Classification)\My_Solution
# .\Project_1_Road_Traffic_Severity(Classification)\My_Solution\.ipynb_checkpoints
# .\Project_1_Road_Traffic_Severity(Classification)\TMLC_Solution
# .\Project_2_Site_Energy_Intensity_Prediction(Regression)
# .\Project_2_Site_Energy_Intensity_Prediction(Regression)\Dataset
# .\Project_2_Site_Energy_Intensity_Prediction(Regression)\Desc_and_PS
# .\Project_2_Site_Energy_Intensity_Prediction(Regression)\My_Solution
# .\Project_2_Site_Energy_Intensity_Prediction(Regression)\TMLC_Solution
# .\Project_3_Wild_Blueberry_Yield_Prediction(Regression)
# .\Project_3_Wild_Blueberry_Yield_Prediction(Regression)\Dataset
# .\Project_3_Wild_Blueberry_Yield_Prediction(Regression)\Desc_and_PS
# .\Project_3_Wild_Blueberry_Yield_Prediction(Regression)\My_Solution
# .\Project_3_Wild_Blueberry_Yield_Prediction(Regression)\TMLC_Solution
# .\Project_4_Patient_Survival_Prediction(Imbalanaced_Classfication)
# .\Project_4_Patient_Survival_Prediction(Imbalanaced_Classfication)\Dataset
# .\Project_4_Patient_Survival_Prediction(Imbalanaced_Classfication)\Desc_and_PS
# .\Project_4_Patient_Survival_Prediction(Imbalanaced_Classfication)\Extra_Resources
# .\Project_4_Patient_Survival_Prediction(Imbalanaced_Classfication)\My_Solution
# .\Project_4_Patient_Survival_Prediction(Imbalanaced_Classfication)\TMLC_Solution
# .\Project_5_Higgs_Boson_Event_Detection(Classification)
# .\Project_5_Higgs_Boson_Event_Detection(Classification)\Dataset
# .\Project_5_Higgs_Boson_Event_Detection(Classification)\Desc_and_PS
# .\Project_5_Higgs_Boson_Event_Detection(Classification)\My_Solution
# .\Project_5_Higgs_Boson_Event_Detection(Classification)\TMLC_Solution
# .\Project_6_DMSP_Particle_Precipitate_Flux_Prediction_Mesoscale(Regression)
# .\Project_6_DMSP_Particle_Precipitate_Flux_Prediction_Mesoscale(Regression)\Dataset
# .\Project_6_DMSP_Particle_Precipitate_Flux_Prediction_Mesoscale(Regression)\Desc_and_PS
# .\Project_6_DMSP_Particle_Precipitate_Flux_Prediction_Mesoscale(Regression)\My_Solution
# .\Project_6_DMSP_Particle_Precipitate_Flux_Prediction_Mesoscale(Regression)\TMLC_Solution
# .\Project_7_Cyberbullying_Detection(Text_Classification)
# .\Project_7_Cyberbullying_Detection(Text_Classification)\Dataset
# .\Project_7_Cyberbullying_Detection(Text_Classification)\Desc_and_PS
# .\Project_7_Cyberbullying_Detection(Text_Classification)\Extra_Resources
# .\Project_7_Cyberbullying_Detection(Text_Classification)\My_Solution
# .\Project_7_Cyberbullying_Detection(Text_Classification)\TMLC_Solution
# .\Project_8_Game_Of_Thrones(Text_Generation)
# .\Project_8_Game_Of_Thrones(Text_Generation)\Dataset
# .\Project_8_Game_Of_Thrones(Text_Generation)\Desc_and_PS
# .\Project_8_Game_Of_Thrones(Text_Generation)\My_Solution
# .\Project_8_Game_Of_Thrones(Text_Generation)\TMLC_Solution
# .\Project_9_English_to_Hindi(Text_Translation)
# .\Project_9_English_to_Hindi(Text_Translation)\Dataset
# .\Project_9_English_to_Hindi(Text_Translation)\Desc_and_PS
# .\Project_9_English_to_Hindi(Text_Translation)\My_Solution
# .\Project_9_English_to_Hindi(Text_Translation)\TMLC_Solution

# %%
for dirpath, dirs, files in os.walk("."):
   print(dirs) # prints the names of existing subdirectories
# Out:
# ['.ipynb_checkpoints', 'Project_10_Plant Seedling Classification(Image_Classification)', 'Project_11_Racoon_Detection(Object_Detection)', 'Project_12_Water_body_segmentation_in_Satellite_Images(Image_Segmentation)', 'Project_1_Road_Traffic_Severity(Classification)', 'Project_2_Site_Energy_Intensity_Prediction(Regression)', 'Project_3_Wild_Blueberry_Yield_Prediction(Regression)', 'Project_4_Patient_Survival_Prediction(Imbalanaced_Classfication)', 'Project_5_Higgs_Boson_Event_Detection(Classification)', 'Project_6_DMSP_Particle_Precipitate_Flux_Prediction_Mesoscale(Regression)', 'Project_7_Cyberbullying_Detection(Text_Classification)', 'Project_8_Game_Of_Thrones(Text_Generation)', 'Project_9_English_to_Hindi(Text_Translation)']
# []
# ['Dataset', 'Desc_and_PS', 'Extra_Resources', 'My_Solution', 'TMLC_Solution']
# []
# []
# []
# []
# []
# ['Dataset', 'Desc_and_PS', 'My_Solution', 'TMLC_Solution']
# []
# []
# []
# []
# ['Dataset', 'Desc_and_PS', 'Extra_Resources', 'My_Solution', 'TMLC_Solution']
# []
# []
# []
# ['.ipynb_checkpoints']
# []
# []
# ['Dataset', 'Desc_and_PS', 'Extra_Resources', 'My_Solution', 'TMLC_Solution']
# []
# []
# []
# ['.ipynb_checkpoints']
# []
# []
# ['Dataset', 'Desc_and_PS', 'My_Solution', 'TMLC_Solution']
# []
# []
# []
# []
# ['Dataset', 'Desc_and_PS', 'My_Solution', 'TMLC_Solution']
# []
# []
# []
# []
# ['Dataset', 'Desc_and_PS', 'Extra_Resources', 'My_Solution', 'TMLC_Solution']
# []
# []
# []
# []
# []
# ['Dataset', 'Desc_and_PS', 'My_Solution', 'TMLC_Solution']
# []
# []
# []
# []
# ['Dataset', 'Desc_and_PS', 'My_Solution', 'TMLC_Solution']
# []
# []
# []
# []
# ['Dataset', 'Desc_and_PS', 'Extra_Resources', 'My_Solution', 'TMLC_Solution']
# []
# []
# []
# []
# []
# ['Dataset', 'Desc_and_PS', 'My_Solution', 'TMLC_Solution']
# []
# []
# []
# []
# ['Dataset', 'Desc_and_PS', 'My_Solution', 'TMLC_Solution']
# []
# []
# []
# []

# %%
for dirpath, dirs, files in os.walk("."):
   print(files) # prints existing files in the current directory
# Out:
# ['Navigate_through_directories.ipynb']
# ['Navigate_through_directories-checkpoint.ipynb']
# []
# ['NonsegmentedV2.zip', 'Source_of_data.txt']
# ['Description.txt', 'Problem_Statement.txt']
# ['CNN for Image Classification.pdf', 'links.txt']
# []
# ['Plant_Seedling_Classification.ipynb']
# []
# ['Racoon Detection.zip', 'Source_of_data.txt']
# ['Description.txt', 'Problem_Statement.txt']
# []
# ['racoon_detection.ipynb']
# []
# ['Segmentation Dataset.zip', 'Source_of_data.txt']
# ['Description.txt', 'Problem_Statement.txt']
# ['links.txt']
# ['Water_Body_Segmentation.ipynb']
# ['Water_Body_Segmentation-checkpoint.ipynb']
# ['Image_Segmentation_with_U_Net_Like_Architecture.ipynb', 'Segmentation_and_Object_Detection.ipynb', 'water-bodies-segmentation-with-unet-and-tensorflow.ipynb']
# []
# ['RTA_Dataset.csv', 'Source_of_data.txt']
# ['Description.txt', 'Problem_Statement.txt']
# ['DIY_RTA_SHAP.ipynb', 'links.docx', 'MGP_Beginners.ipynb', 'Procedure.docx']
# ['Accident_Prediction.ipynb']
# ['Accident_Prediction-checkpoint.ipynb']
# ['ML Template For Beginners.ipynb', '[New]Guided_SampleNotebook_RTADataset.ipynb']
# []
# ['Source_of_data.txt', 'train_dataset.csv', 'x_test.csv', 'y_test.csv']
# ['Description.txt', 'Problem_Statement.txt']
# []
# ['[New]Guided_SampleNotebook_SiteEUIPrediction_WiDS22.ipynb']
# []
# ['Data_in_brief_WildBlueberryPollinationSimulation.docx', 'Source_of_data.txt', 'WildBlueberryPollinationSimulationData.csv', 'Wild_blueberry_yield_prediction_using_a_combination_of_computer_simulation.pdf']
# ['Description.txt', 'Problem_Statement.txt']
# []
# ['[New]Guided_SampleNotebook_WildBberryPollSimPred.ipynb']
# []
# ['Dataset.csv', 'Data_Dictionary.csv', 'Source_of_data.txt']
# ['Description.txt', 'Problem_Statement.txt']
# ['Deep Learning basic flow.pdf', 'DL1_Patient _Survival_notebook.ipynb', 'Guided_Patient_Survival_Prediction.ipynb', 'links.txt', 'pytorch-nn-baseline-for-beginners.ipynb']
# []
# ['DL1_Patient _Survival_notebook.ipynb', 'Guided_Patient_Survival_Prediction.ipynb', 'pytorch-nn-baseline-for-beginners.ipynb']
# []
# ['Dataset_Details.docx', 'Dataset_Details.pdf', 'In-depth_details.pdf', 'Searching_for_Higgs_Boson_Decay_Modes_with_Deep_Learning.pdf', 'Source_of_data.txt', 'training.csv']
# ['Description.txt', 'Problem_Statement.txt']
# []
# ['higgsbosoneventdetection.ipynb']
# []
# ['AI_Ready_DMSP_Data.csv', 'Source_of_data.txt']
# ['Description.txt', 'Problem_Statement.txt']
# []
# ['DMSP_Particle_Precipitation.ipynb']
# []
# ['Source_of_data.txt', 'twitter_parsed_dataset.csv']
# ['Description.txt', 'Problem_Statement.txt']
# ['links.docx', 'NLP_Basics.ipynb', 'NLP_Complete.ipynb', 'Text generation using Deep Learning.pdf']
# []
# ['Guided_Cyberberbullying_TextClassification_NLP.ipynb']
# []
# ['got1.txt', 'Source_of_data.txt']
# ['Description.txt', 'Problem_Statement.txt']
# []
# ['Building_RNN_Text_Generation.ipynb']
# []
# ['hindi_english_parallel.csv', 'Source_of_data.txt']
# ['Description.txt', 'Problem_Statement.txt']
# []
# ['english-hindi-machine-translation.ipynb']
